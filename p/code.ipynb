# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from api_keys import m_key
from time import sleep

# %%
url= 'https://data.cdc.gov/resource/8pt5-q6wp.json'
response = requests.get(url)

response_json = response.json()
response_json
# Out:
# [{'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'National Estimate',
#   'state': 'United States',
#   'subgroup': 'United States',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.5',
#   'lowci': '22.7',
#   'highci': '24.3',
#   'confidence_interval': '22.7 - 24.3'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '18 - 29 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '32.7',
#   'lowci': '30.2',
#   'highci': '35.2',
#   'confidence_interval': '30.2 - 35.2'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '30 - 39 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.7',
#   'lowci': '24.1',
#   'highci': '27.3',
#   'confidence_interval': '24.1 - 27.3'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '40 - 49 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '24.8',
#   'lowci': '23.3',
#   'highci': '26.2',
#   'confidence_interval': '23.3 - 26.2'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '50 - 59 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.2',
#   'lowci': '21.5',
#   'highci': '25',
#   'confidence_interval': '21.5 - 25.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '60 - 69 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '18.4',
#   'lowci': '17',
#   'highci': '19.7',
#   'confidence_interval': '17.0 - 19.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '70 - 79 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '13.6',
#   'lowci': '11.8',
#   'highci': '15.5',
#   'confidence_interval': '11.8 - 15.5'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '80 years and above',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '14.4',
#   'lowci': '9',
#   'highci': '21.4',
#   'confidence_interval': '9.0 - 21.4'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Sex',
#   'state': 'United States',
#   'subgroup': 'Male',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '20.8',
#   'lowci': '19.6',
#   'highci': '22',
#   'confidence_interval': '19.6 - 22.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Sex',
#   'state': 'United States',
#   'subgroup': 'Female',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.1',
#   'lowci': '25.2',
#   'highci': '27.1',
#   'confidence_interval': '25.2 - 27.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Hispanic or Latino',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '29.4',
#   'lowci': '26.8',
#   'highci': '32.1',
#   'confidence_interval': '26.8 - 32.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic White, single race',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '21.4',
#   'lowci': '20.6',
#   'highci': '22.1',
#   'confidence_interval': '20.6 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic Black, single race',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.6',
#   'lowci': '23.7',
#   'highci': '27.5',
#   'confidence_interval': '23.7 - 27.5'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic Asian, single race',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.6',
#   'lowci': '20.3',
#   'highci': '27.1',
#   'confidence_interval': '20.3 - 27.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic, other races and multiple races',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '28.3',
#   'lowci': '24.8',
#   'highci': '32',
#   'confidence_interval': '24.8 - 32.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': 'Less than a high school diploma',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '32.7',
#   'lowci': '27.8',
#   'highci': '38',
#   'confidence_interval': '27.8 - 38.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': 'High school diploma or GED',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.4',
#   'lowci': '23.9',
#   'highci': '26.9',
#   'confidence_interval': '23.9 - 26.9'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': "Some college/Associate's degree",
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.6',
#   'lowci': '24.4',
#   'highci': '26.9',
#   'confidence_interval': '24.4 - 26.9'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': "Bachelor's degree or higher",
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '17.6',
#   'lowci': '16.8',
#   'highci': '18.4',
#   'confidence_interval': '16.8 - 18.4'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Alabama',
#   'subgroup': 'Alabama',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '18.6',
#   'lowci': '14.6',
#   'highci': '23.1',
#   'confidence_interval': '14.6 - 23.1',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Alaska',
#   'subgroup': 'Alaska',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '19.2',
#   'lowci': '16.8',
#   'highci': '21.8',
#   'confidence_interval': '16.8 - 21.8',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Arizona',
#   'subgroup': 'Arizona',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.4',
#   'lowci': '19.4',
#   'highci': '25.5',
#   'confidence_interval': '19.4 - 25.5',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Arkansas',
#   'subgroup': 'Arkansas',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.6',
#   'lowci': '22.3',
#   'highci': '31.3',
#   'confidence_interval': '22.3 - 31.3',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'California',
#   'subgroup': 'California',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.4',
#   'lowci': '22.5',
#   'highci': '28.6',
#   'confidence_interval': '22.5 - 28.6',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Colorado',
#   'subgroup': 'Colorado',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22',
#   'lowci': '19.4',
#   'highci': '24.9',
#   'confidence_interval': '19.4 - 24.9',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Connecticut',
#   'subgroup': 'Connecticut',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '24.4',
#   'lowci': '20.1',
#   'highci': '29.1',
#   'confidence_interval': '20.1 - 29.1',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Delaware',
#   'subgroup': 'Delaware',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '21.1',
#   'lowci': '17.6',
#   'highci': '24.9',
#   'confidence_interval': '17.6 - 24.9',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'District of Columbia',
#   'subgroup': 'District of Columbia',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.4',
#   'lowci': '22.1',
#   'highci': '31.1',
#   'confidence_interval': '22.1 - 31.1',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Florida',
#   'subgroup': 'Florida',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.5',
#   'lowci': '19.7',
#   'highci': '25.4',
#   'confidence_interval': '19.7 - 25.4',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Georgia',
#   'subgroup': 'Georgia',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.6',
#   'lowci': '21.4',
#   'highci': '30.2',
#   'confidence_interval': '21.4 - 30.2',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Hawaii',
#   'subgroup': 'Hawaii',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '20',
#   'lowci': '14.9',
#   'highci': '26.1',
#   'confidence_interval': '14.9 - 26.1',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Idaho',
#   'subgroup': 'Idaho',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '20.6',
#   'lowci': '17.3',
#   'highci': '24.1',
#   'confidence_interval': '17.3 - 24.1',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Illinois',
#   'subgroup': 'Illinois',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.3',
#   'lowci': '19.6',
#   'highci': '27.2',
#   'confidence_interval': '19.6 - 27.2',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Indiana',
#   'subgroup': 'Indiana',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.4',
#   'lowci': '22.1',
#   'highci': '31',
#   'confidence_interval': '22.1 - 31.0',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Iowa',
#   'subgroup': 'Iowa',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '16.5',
#   'lowci': '13.7',
#   'highci': '19.6',
#   'confidence_interval': '13.7 - 19.6',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Kansas',
#   'subgroup': 'Kansas',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.1',
#   'lowci': '18.3',
#   'highci': '26.4',
#   'confidence_interval': '18.3 - 26.4',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Kentucky',
#   'subgroup': 'Kentucky',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.2',
#   'lowci': '19.4',
#   'highci': '27.4',
#   'confidence_interval': '19.4 - 27.4',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Louisiana',
#   'subgroup': 'Louisiana',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '28.1',
#   'lowci': '24.1',
#   'highci': '32.4',
#   'confidence_interval': '24.1 - 32.4',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Maine',
#   'subgroup': 'Maine',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '19.5',
#   'lowci': '16',
#   'highci': '23.5',
#   'confidence_interval': '16.0 - 23.5',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Maryland',
#   'subgroup': 'Maryland',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '20.9',
#   'lowci': '17.9',
#   'highci': '24.1',
#   'confidence_interval': '17.9 - 24.1',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Massachusetts',
#   'subgroup': 'Massachusetts',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.9',
#   'lowci': '22.7',
#   'highci': '29.4',
#   'confidence_interval': '22.7 - 29.4',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Michigan',
#   'subgroup': 'Michigan',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.5',
#   'lowci': '22',
#   'highci': '29.4',
#   'confidence_interval': '22.0 - 29.4',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Minnesota',
#   'subgroup': 'Minnesota',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '20.4',
#   'lowci': '17.7',
#   'highci': '23.4',
#   'confidence_interval': '17.7 - 23.4',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Mississippi',
#   'subgroup': 'Mississippi',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.9',
#   'lowci': '18.7',
#   'highci': '27.6',
#   'confidence_interval': '18.7 - 27.6',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Missouri',
#   'subgroup': 'Missouri',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '21',
#   'lowci': '17.9',
#   'highci': '24.5',
#   'confidence_interval': '17.9 - 24.5',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Montana',
#   'subgroup': 'Montana',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '18.2',
#   'lowci': '14.9',
#   'highci': '21.8',
#   'confidence_interval': '14.9 - 21.8',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Nebraska',
#   'subgroup': 'Nebraska',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '19.1',
#   'lowci': '15.3',
#   'highci': '23.3',
#   'confidence_interval': '15.3 - 23.3',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Nevada',
#   'subgroup': 'Nevada',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.6',
#   'lowci': '19.1',
#   'highci': '28.7',
#   'confidence_interval': '19.1 - 28.7',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'New Hampshire',
#   'subgroup': 'New Hampshire',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '19.5',
#   'lowci': '16.5',
#   'highci': '22.7',
#   'confidence_interval': '16.5 - 22.7',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'New Jersey',
#   'subgroup': 'New Jersey',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.6',
#   'lowci': '20.4',
#   'highci': '27',
#   'confidence_interval': '20.4 - 27.0',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'New Mexico',
#   'subgroup': 'New Mexico',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.4',
#   'lowci': '18.3',
#   'highci': '26.9',
#   'confidence_interval': '18.3 - 26.9',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'New York',
#   'subgroup': 'New York',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '28.7',
#   'lowci': '24.6',
#   'highci': '33.1',
#   'confidence_interval': '24.6 - 33.1',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'North Carolina',
#   'subgroup': 'North Carolina',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '21.1',
#   'lowci': '17.1',
#   'highci': '25.6',
#   'confidence_interval': '17.1 - 25.6',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'North Dakota',
#   'subgroup': 'North Dakota',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '17',
#   'lowci': '13.7',
#   'highci': '20.7',
#   'confidence_interval': '13.7 - 20.7',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Ohio',
#   'subgroup': 'Ohio',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '21.2',
#   'lowci': '18.2',
#   'highci': '24.5',
#   'confidence_interval': '18.2 - 24.5',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Oklahoma',
#   'subgroup': 'Oklahoma',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '20.8',
#   'lowci': '16.4',
#   'highci': '25.7',
#   'confidence_interval': '16.4 - 25.7',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Oregon',
#   'subgroup': 'Oregon',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.5',
#   'lowci': '19.7',
#   'highci': '25.4',
#   'confidence_interval': '19.7 - 25.4',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Pennsylvania',
#   'subgroup': 'Pennsylvania',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '24.7',
#   'lowci': '21.6',
#   'highci': '28.1',
#   'confidence_interval': '21.6 - 28.1',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Rhode Island',
#   'subgroup': 'Rhode Island',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '24.5',
#   'lowci': '19.9',
#   'highci': '29.7',
#   'confidence_interval': '19.9 - 29.7',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'South Carolina',
#   'subgroup': 'South Carolina',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '21.6',
#   'lowci': '17.9',
#   'highci': '25.7',
#   'confidence_interval': '17.9 - 25.7',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'South Dakota',
#   'subgroup': 'South Dakota',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '17.5',
#   'lowci': '13',
#   'highci': '22.7',
#   'confidence_interval': '13.0 - 22.7',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Tennessee',
#   'subgroup': 'Tennessee',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.2',
#   'lowci': '17.2',
#   'highci': '27.8',
#   'confidence_interval': '17.2 - 27.8',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Texas',
#   'subgroup': 'Texas',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '24.4',
#   'lowci': '21.1',
#   'highci': '27.9',
#   'confidence_interval': '21.1 - 27.9',
#   'quartile_range': '24.1 - 28.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Utah',
#   'subgroup': 'Utah',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.9',
#   'lowci': '20',
#   'highci': '26',
#   'confidence_interval': '20.0 - 26.0',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Vermont',
#   'subgroup': 'Vermont',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '20.7',
#   'lowci': '15.9',
#   'highci': '26.3',
#   'confidence_interval': '15.9 - 26.3',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Virginia',
#   'subgroup': 'Virginia',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '21.5',
#   'lowci': '18',
#   'highci': '25.3',
#   'confidence_interval': '18.0 - 25.3',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Washington',
#   'subgroup': 'Washington',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.1',
#   'lowci': '19.7',
#   'highci': '24.7',
#   'confidence_interval': '19.7 - 24.7',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'West Virginia',
#   'subgroup': 'West Virginia',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '23.4',
#   'lowci': '19.5',
#   'highci': '27.6',
#   'confidence_interval': '19.5 - 27.6',
#   'quartile_range': '22.2 - 24.0'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Wisconsin',
#   'subgroup': 'Wisconsin',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22',
#   'lowci': '19.2',
#   'highci': '25',
#   'confidence_interval': '19.2 - 25.0',
#   'quartile_range': '20.8 - 22.1'},
#  {'indicator': 'Symptoms of Depressive Disorder',
#   'group': 'By State',
#   'state': 'Wyoming',
#   'subgroup': 'Wyoming',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '18.9',
#   'lowci': '15.3',
#   'highci': '22.9',
#   'confidence_interval': '15.3 - 22.9',
#   'quartile_range': '16.5 - 20.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'National Estimate',
#   'state': 'United States',
#   'subgroup': 'United States',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '30.8',
#   'lowci': '30',
#   'highci': '31.7',
#   'confidence_interval': '30.0 - 31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '18 - 29 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '40.2',
#   'lowci': '38.1',
#   'highci': '42.4',
#   'confidence_interval': '38.1 - 42.4'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '30 - 39 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '34.4',
#   'lowci': '32.6',
#   'highci': '36.1',
#   'confidence_interval': '32.6 - 36.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '40 - 49 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '34.1',
#   'lowci': '32.1',
#   'highci': '36.2',
#   'confidence_interval': '32.1 - 36.2'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '50 - 59 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '31',
#   'lowci': '29',
#   'highci': '33.1',
#   'confidence_interval': '29.0 - 33.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '60 - 69 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '24.9',
#   'lowci': '23.6',
#   'highci': '26.3',
#   'confidence_interval': '23.6 - 26.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '70 - 79 years',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '16.4',
#   'lowci': '14.8',
#   'highci': '18.1',
#   'confidence_interval': '14.8 - 18.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '80 years and above',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '14.6',
#   'lowci': '11.5',
#   'highci': '18.2',
#   'confidence_interval': '11.5 - 18.2'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Sex',
#   'state': 'United States',
#   'subgroup': 'Male',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.1',
#   'lowci': '24.7',
#   'highci': '27.5',
#   'confidence_interval': '24.7 - 27.5'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Sex',
#   'state': 'United States',
#   'subgroup': 'Female',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '35.4',
#   'lowci': '34.5',
#   'highci': '36.3',
#   'confidence_interval': '34.5 - 36.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Hispanic or Latino',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '36.3',
#   'lowci': '33.4',
#   'highci': '39.2',
#   'confidence_interval': '33.4 - 39.2'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic White, single race',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '29',
#   'lowci': '28.2',
#   'highci': '29.9',
#   'confidence_interval': '28.2 - 29.9'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic Black, single race',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '32.8',
#   'lowci': '30.3',
#   'highci': '35.5',
#   'confidence_interval': '30.3 - 35.5'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic Asian, single race',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.3',
#   'lowci': '23.6',
#   'highci': '29.1',
#   'confidence_interval': '23.6 - 29.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic, other races and multiple races',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '38.2',
#   'lowci': '34.3',
#   'highci': '42.3',
#   'confidence_interval': '34.3 - 42.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': 'Less than a high school diploma',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '37.3',
#   'lowci': '32.4',
#   'highci': '42.4',
#   'confidence_interval': '32.4 - 42.4'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': 'High school diploma or GED',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '30.6',
#   'lowci': '29',
#   'highci': '32.3',
#   'confidence_interval': '29.0 - 32.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': "Some college/Associate's degree",
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '33.5',
#   'lowci': '32',
#   'highci': '35.1',
#   'confidence_interval': '32.0 - 35.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': "Bachelor's degree or higher",
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '27',
#   'lowci': '26.3',
#   'highci': '27.8',
#   'confidence_interval': '26.3 - 27.8'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Alabama',
#   'subgroup': 'Alabama',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '25.6',
#   'lowci': '20.7',
#   'highci': '30.9',
#   'confidence_interval': '20.7 - 30.9',
#   'quartile_range': '21.7 - 27.8'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Alaska',
#   'subgroup': 'Alaska',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '27.7',
#   'lowci': '24.8',
#   'highci': '30.7',
#   'confidence_interval': '24.8 - 30.7',
#   'quartile_range': '21.7 - 27.8'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Arizona',
#   'subgroup': 'Arizona',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '32.3',
#   'lowci': '28',
#   'highci': '36.8',
#   'confidence_interval': '28.0 - 36.8',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Arkansas',
#   'subgroup': 'Arkansas',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '33.7',
#   'lowci': '28.2',
#   'highci': '39.6',
#   'confidence_interval': '28.2 - 39.6',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'California',
#   'subgroup': 'California',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '30.8',
#   'lowci': '28.2',
#   'highci': '33.5',
#   'confidence_interval': '28.2 - 33.5',
#   'quartile_range': '30.4 - 31.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Colorado',
#   'subgroup': 'Colorado',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '32.6',
#   'lowci': '29.2',
#   'highci': '36.2',
#   'confidence_interval': '29.2 - 36.2',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Connecticut',
#   'subgroup': 'Connecticut',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '34.9',
#   'lowci': '30',
#   'highci': '40',
#   'confidence_interval': '30.0 - 40.0',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Delaware',
#   'subgroup': 'Delaware',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '29.9',
#   'lowci': '25.5',
#   'highci': '34.6',
#   'confidence_interval': '25.5 - 34.6',
#   'quartile_range': '27.9 - 30.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'District of Columbia',
#   'subgroup': 'District of Columbia',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '31.4',
#   'lowci': '27.9',
#   'highci': '35.1',
#   'confidence_interval': '27.9 - 35.1',
#   'quartile_range': '30.4 - 31.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Florida',
#   'subgroup': 'Florida',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '32.6',
#   'lowci': '29.7',
#   'highci': '35.6',
#   'confidence_interval': '29.7 - 35.6',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Georgia',
#   'subgroup': 'Georgia',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '31.9',
#   'lowci': '28.1',
#   'highci': '35.9',
#   'confidence_interval': '28.1 - 35.9',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Hawaii',
#   'subgroup': 'Hawaii',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '32.3',
#   'lowci': '27.1',
#   'highci': '37.8',
#   'confidence_interval': '27.1 - 37.8',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Idaho',
#   'subgroup': 'Idaho',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.9',
#   'lowci': '23.7',
#   'highci': '30.2',
#   'confidence_interval': '23.7 - 30.2',
#   'quartile_range': '21.7 - 27.8'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Illinois',
#   'subgroup': 'Illinois',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '31.1',
#   'lowci': '27',
#   'highci': '35.4',
#   'confidence_interval': '27.0 - 35.4',
#   'quartile_range': '30.4 - 31.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Indiana',
#   'subgroup': 'Indiana',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '31.8',
#   'lowci': '27.5',
#   'highci': '36.4',
#   'confidence_interval': '27.5 - 36.4',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Iowa',
#   'subgroup': 'Iowa',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '22.5',
#   'lowci': '19',
#   'highci': '26.2',
#   'confidence_interval': '19.0 - 26.2',
#   'quartile_range': '21.7 - 27.8'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Kansas',
#   'subgroup': 'Kansas',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '26.4',
#   'lowci': '22',
#   'highci': '31.2',
#   'confidence_interval': '22.0 - 31.2',
#   'quartile_range': '21.7 - 27.8'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Kentucky',
#   'subgroup': 'Kentucky',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '31.6',
#   'lowci': '28.1',
#   'highci': '35.3',
#   'confidence_interval': '28.1 - 35.3',
#   'quartile_range': '30.4 - 31.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Louisiana',
#   'subgroup': 'Louisiana',
#   'phase': '1',
#   'time_period': '1',
#   'time_period_label': 'Apr 23 - May 5, 2020',
#   'time_period_start_date': '2020-04-23T00:00:00.000',
#   'time_period_end_date': '2020-05-05T00:00:00.000',
#   'value': '34.4',
#   'lowci': '29.7',
#   'highci': '39.3',
#   'confidence_interval': '29.7 - 39.3',
#   'quartile_range': '31.7 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Maine',
# ...
#   'value': '29.6',
#   'lowci': '25.4',
#   'highci': '34.1',
#   'confidence_interval': '25.4 - 34.1',
#   'quartile_range': '26.8-29.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Oklahoma',
#   'subgroup': 'Oklahoma',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '31.7',
#   'lowci': '28.1',
#   'highci': '35.6',
#   'confidence_interval': '28.1 - 35.6',
#   'quartile_range': '29.7-31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Oregon',
#   'subgroup': 'Oregon',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '35.3',
#   'lowci': '31.5',
#   'highci': '39.2',
#   'confidence_interval': '31.5 - 39.2',
#   'quartile_range': '31.8-37.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Pennsylvania',
#   'subgroup': 'Pennsylvania',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '31.4',
#   'lowci': '27',
#   'highci': '36',
#   'confidence_interval': '27.0 - 36.0',
#   'quartile_range': '29.7-31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Rhode Island',
#   'subgroup': 'Rhode Island',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '30.8',
#   'lowci': '25.6',
#   'highci': '36.5',
#   'confidence_interval': '25.6 - 36.5',
#   'quartile_range': '29.7-31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'South Carolina',
#   'subgroup': 'South Carolina',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '29.2',
#   'lowci': '24.4',
#   'highci': '34.4',
#   'confidence_interval': '24.4 - 34.4',
#   'quartile_range': '26.8-29.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'South Dakota',
#   'subgroup': 'South Dakota',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '26.3',
#   'lowci': '21.8',
#   'highci': '31.1',
#   'confidence_interval': '21.8 - 31.1',
#   'quartile_range': '18.4-26.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Tennessee',
#   'subgroup': 'Tennessee',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '30.4',
#   'lowci': '26.4',
#   'highci': '34.6',
#   'confidence_interval': '26.4 - 34.6',
#   'quartile_range': '29.7-31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Texas',
#   'subgroup': 'Texas',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '31.1',
#   'lowci': '27.7',
#   'highci': '34.6',
#   'confidence_interval': '27.7 - 34.6',
#   'quartile_range': '29.7-31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Utah',
#   'subgroup': 'Utah',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '29.7',
#   'lowci': '26.7',
#   'highci': '32.8',
#   'confidence_interval': '26.7 - 32.8',
#   'quartile_range': '29.7-31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Vermont',
#   'subgroup': 'Vermont',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '31.8',
#   'lowci': '25.5',
#   'highci': '38.6',
#   'confidence_interval': '25.5 - 38.6',
#   'quartile_range': '31.8-37.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Virginia',
#   'subgroup': 'Virginia',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '28.3',
#   'lowci': '25',
#   'highci': '31.7',
#   'confidence_interval': '25.0 - 31.7',
#   'quartile_range': '26.8-29.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Washington',
#   'subgroup': 'Washington',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '31.7',
#   'lowci': '28.1',
#   'highci': '35.5',
#   'confidence_interval': '28.1 - 35.5',
#   'quartile_range': '29.7-31.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'West Virginia',
#   'subgroup': 'West Virginia',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '33.6',
#   'lowci': '28',
#   'highci': '39.5',
#   'confidence_interval': '28.0 - 39.5',
#   'quartile_range': '31.8-37.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Wisconsin',
#   'subgroup': 'Wisconsin',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '22.7',
#   'lowci': '19.3',
#   'highci': '26.3',
#   'confidence_interval': '19.3 - 26.3',
#   'quartile_range': '18.4-26.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder',
#   'group': 'By State',
#   'state': 'Wyoming',
#   'subgroup': 'Wyoming',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '25.3',
#   'lowci': '21.2',
#   'highci': '29.7',
#   'confidence_interval': '21.2 - 29.7',
#   'quartile_range': '18.4-26.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'National Estimate',
#   'state': 'United States',
#   'subgroup': 'United States',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '35.5',
#   'lowci': '34.8',
#   'highci': '36.1',
#   'confidence_interval': '34.8 - 36.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '18 - 29 years',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '49.3',
#   'lowci': '47.4',
#   'highci': '51.2',
#   'confidence_interval': '47.4 - 51.2'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '30 - 39 years',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '40.6',
#   'lowci': '39.2',
#   'highci': '42',
#   'confidence_interval': '39.2 - 42.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '40 - 49 years',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '36.9',
#   'lowci': '35.3',
#   'highci': '38.6',
#   'confidence_interval': '35.3 - 38.6'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '50 - 59 years',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '33.6',
#   'lowci': '31.9',
#   'highci': '35.4',
#   'confidence_interval': '31.9 - 35.4'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '60 - 69 years',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '27',
#   'lowci': '25.6',
#   'highci': '28.5',
#   'confidence_interval': '25.6 - 28.5'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '70 - 79 years',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '21.7',
#   'lowci': '19.3',
#   'highci': '24.2',
#   'confidence_interval': '19.3 - 24.2'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Age',
#   'state': 'United States',
#   'subgroup': '80 years and above',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '19.2',
#   'lowci': '14.7',
#   'highci': '24.4',
#   'confidence_interval': '14.7 - 24.4'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Sex',
#   'state': 'United States',
#   'subgroup': 'Male',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '31.1',
#   'lowci': '30.2',
#   'highci': '32.1',
#   'confidence_interval': '30.2 - 32.1'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Sex',
#   'state': 'United States',
#   'subgroup': 'Female',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '39.6',
#   'lowci': '38.9',
#   'highci': '40.3',
#   'confidence_interval': '38.9 - 40.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Hispanic or Latino',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '38.3',
#   'lowci': '36.2',
#   'highci': '40.4',
#   'confidence_interval': '36.2 - 40.4'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic White, single race',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '33.1',
#   'lowci': '32.3',
#   'highci': '33.9',
#   'confidence_interval': '32.3 - 33.9'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic Black, single race',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '40.5',
#   'lowci': '38.3',
#   'highci': '42.7',
#   'confidence_interval': '38.3 - 42.7'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic Asian, single race',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '34.2',
#   'lowci': '31.6',
#   'highci': '37',
#   'confidence_interval': '31.6 - 37.0'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Race/Hispanic ethnicity',
#   'state': 'United States',
#   'subgroup': 'Non-Hispanic, other races and multiple races',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '49.6',
#   'lowci': '45.9',
#   'highci': '53.4',
#   'confidence_interval': '45.9 - 53.4'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': 'Less than a high school diploma',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '43.9',
#   'lowci': '40.4',
#   'highci': '47.5',
#   'confidence_interval': '40.4 - 47.5'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': 'High school diploma or GED',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '36.7',
#   'lowci': '35.1',
#   'highci': '38.3',
#   'confidence_interval': '35.1 - 38.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': "Some college/Associate's degree",
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '38.3',
#   'lowci': '37.2',
#   'highci': '39.4',
#   'confidence_interval': '37.2 - 39.4'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By Education',
#   'state': 'United States',
#   'subgroup': "Bachelor's degree or higher",
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '29.4',
#   'lowci': '28.5',
#   'highci': '30.3',
#   'confidence_interval': '28.5 - 30.3'},
#  {'indicator': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#   'group': 'By State',
#   'state': 'Alabama',
#   'subgroup': 'Alabama',
#   'phase': '1',
#   'time_period': '5',
#   'time_period_label': 'May 28 - June 2, 2020',
#   'time_period_start_date': '2020-05-28T00:00:00.000',
#   'time_period_end_date': '2020-06-02T00:00:00.000',
#   'value': '37.5',
#   'lowci': '32.6',
#   'highci': '42.6',
#   'confidence_interval': '32.6 - 42.6',
#   'quartile_range': '37.0-40.0'}]
